# %%
import os
from dotenv import load_dotenv
from qiskit_ibm_runtime import QiskitRuntimeService

load_dotenv()

token = os.getenv("IBM_QUANTUM_TOKEN")
if not token:
    raise ValueError("No IBM_QUANTUM_TOKEN in env/.env.")

QiskitRuntimeService.save_account(
    channel="ibm_quantum_platform",
    token=token,
    overwrite=True
)

service = QiskitRuntimeService(channel="ibm_quantum_platform")

# %%
backend = service.least_busy(operational=True, simulator=False)
print(f"Wybrany komputer: {backend.name}")
# Out:
# qiskit_runtime_service.backends:WARNING:2026-02-23 19:25:48,376: Loading instance: eburdak, plan: open
# qiskit_runtime_service.backends:WARNING:2026-02-23 19:25:51,664: Using instance: eburdak, plan: open
# Wybrany komputer: ibm_torino
